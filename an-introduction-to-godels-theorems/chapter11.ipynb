# %% [markdown]
# # 11.1 Capturing *less-than-or-equal-to* in Q
#
# ## pp. 71-72 derivation inside Q
#
# just try to understand this proof as we understand a standard proof in math. While the proof is purely **syntactical**, its style (natrual deduction) mimics that of standard math proof a lot.
#
# # 11.5 $\Sigma_1$ and  $\Pi_1$ wffs
#
# ## pp. 76 Q can prove all true $\Delta_0$ sentences for its boundedness.
#
# > [Q] can prove all the true $\Delta_0$ sentences and refute all the false ones, because everything is bounded.
#
# ## pp. 77 these two types of wffs are pretty general.
#
# >  Because --- looking ahead --- it turns out that $\Sigma_1$ wffs are just what we need to express and capture computable numerical functions and effectively decidable properties of numbers.
#
# ## pp. 77 multiple equivalent definitions of these wffs.
#
# footnote 6.
#
# ## pp. 78 Thm 10.4 logical equivalence of some wffs.
#
# notice it's **logical** equivalence. check my note below. Contrast this with **provable** equivalence.
#
# >  Given enough background setting, the various versions are equivalent.
#
# I think "background setting" means some conditions on deduction system, etc.
#
# # 11.7 Intriguing corollaries
#
# ## pp. 80 Thm 11.6 One way to tell truth of $\Pi_1$ sentences by examining Q.
#
# "consistent with" simply means "$\neg \phi$ not provable". Otherwise, $\phi$ plus axioms in $Q$ definitely won't be consistent, as we will be able to derive $\phi$ and $\neg \phi$, which is contradiction. By Gödel's completeness theorem, "$\neg \phi$ not provable" means that $\phi$ plus axioms in $Q$ has a model (assuming $Q$ is consistent).
#
# The note at the end of this page is messy. I think they can remove "we'd have a method for deciding whether Q is consistent (take $\phi$ to be a contradiction)". I think the intention of checking Q's consistency is to make sure we can use Thm 11.6 in the next sentence ("and hence a method for deciding the truth or falsity of any ..."). However, Thm 11.6 assumes soundness, which is stronger than consistency.
#
# Also, as you talk about truth or falsity of arithmetic sentences, I think you implicitly assumed that Q has the standard arithmetic as a model, and all the argument about Q's soundness simply follows. So there's no need to check Q's consistency. As long as you want to check some arithmetic sentences' truth values, you automatically make Q sound (and thus consistent).
#
#
# ## pp. 81 provability is not decidable.
#
# > Questions of deducibility in first-order logic are not, in general, effectively decidable: that's Theorem 40.3.
#
# ## pp. 81 Thm 11.7 as long as T is a consistent extension of Q, we can buy its $\Pi_1$ theorems.
#
# I think (c) here is messed up in writing and logic. I'd rather only take the last take home message.
#
# > Which is an emphatic illustration that even really rather simple theories may not wear their consistency on their face.
#
# # 11.8 Proving Q is order-adequate
#
# Again, as in 11.1, just try to understand these proofs as we understand standard proofs in math.
#
# There are some difference.
#
# For example, to prove $\forall a \phi(a)$, you need to first prove $\phi(a)$ where $a$ is a free variable. Then use generalization rule (check [Mathematical Logic and Model Theory](https://doi.org/10.1007/978-1-4471-2176-3)) to add that $\forall$ symbol.
#
# With this in mind, you should now understand the proof of (O1) better, as well as others better. $a + 0 = a$ is simply proved by axiom 4.

# %% [markdown]
# # new concepts
#
# ## bounded quantifiers
#
# Given in 11.2. just a notational convenience.
#
# ## $\Delta_0$ wffs.
#
# Defined in 11.4. wffs with bounded quantifiers.
#
# also called $\Sigma_0$ wffs. See footnote 8 on pp. 79.
#
#
# ## $\Sigma_1$ and  $\Pi_1$ wffs
#
# Defined in 11.5. Essentially, they are $\Delta_0$ wffs with a number of existential or universal quantifiers outside, respectively.
#
# ## logical equivalence -- a languge interpretation related concept
#
# check https://en.wikipedia.org/wiki/Logical_equivalence. Basically this means that two sentences have the same value in each of possible all models (and under any given evaluation of free variables, I guess; check [Mathematical Logic and Model Theory](https://doi.org/10.1007/978-1-4471-2176-3) for what evaluation means).
#
# > two statements are [logically] equivalent if they have the same truth value in every model (Mendelson 1979:56)
#
# ## provable equivalence -- a theory related concept
#
# this means that if you can prove one wff, then you can prove another and vice versa.
#
# I believe, by the way authors construct the proof for Thm 12.2 in pp. 87, for  provable sentences, logically equivalence implies provable equivalence (given a strong enough deduction system)?
#
# > is provably equivalent in ... to ... which is logically equivalent ...
